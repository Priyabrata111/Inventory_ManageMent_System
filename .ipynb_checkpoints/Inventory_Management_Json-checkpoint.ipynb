# %%
records = {
    1: {"Name": "Redmi Note 7 Pro", "Price": 15000, "Quantity": 10},
    2: {"Name": "Samsung Galaxy M14", "Price": 13000, "Quantity": 8},
    3: {"Name": "iPhone SE", "Price": 30000, "Quantity": 5},
    4: {"Name": "Realme Narzo 60", "Price": 17000, "Quantity": 12},
    5: {"Name": "OnePlus Nord CE", "Price": 25000, "Quantity": 6},
    6: {"Name": "Vivo T1", "Price": 16000, "Quantity": 9},
    7: {"Name": "Poco X5", "Price": 18000, "Quantity": 7},
    8: {"Name": "Motorola G54", "Price": 14000, "Quantity": 11},
    9: {"Name": "Oppo A78", "Price": 19000, "Quantity": 4},
    10: {"Name": "Redmi 13C", "Price": 9000, "Quantity": 15}
}

# %%
print(records)
# Out:
# {1: {'Name': 'Redmi Note 7 Pro', 'Price': 15000, 'Quantity': 10}, 2: {'Name': 'Samsung Galaxy M14', 'Price': 13000, 'Quantity': 8}, 3: {'Name': 'iPhone SE', 'Price': 30000, 'Quantity': 5}, 4: {'Name': 'Realme Narzo 60', 'Price': 17000, 'Quantity': 12}, 5: {'Name': 'OnePlus Nord CE', 'Price': 25000, 'Quantity': 6}, 6: {'Name': 'Vivo T1', 'Price': 16000, 'Quantity': 9}, 7: {'Name': 'Poco X5', 'Price': 18000, 'Quantity': 7}, 8: {'Name': 'Motorola G54', 'Price': 14000, 'Quantity': 11}, 9: {'Name': 'Oppo A78', 'Price': 19000, 'Quantity': 4}, 10: {'Name': 'Redmi 13C', 'Price': 9000, 'Quantity': 15}}

# %%
print("---------------------------------------------------  Product Details ---------------------------------------------\n")

for key,v in records.items():
    print(f"Product Id : {key} | Product Name : {records[key]['Name']} | Product Price : {records[key]['Price']} | Product Quantity Avaiable :{records[key]['Quantity']}")

print("\n-------------------------------------------------------------------------------------------------------------------\n")
# Out:
# ---------------------------------------------------  Product Details ---------------------------------------------
#
# Product Id : 1 | Product Name : Redmi Note 7 Pro | Product Price : 15000 | Product Quantity Avaiable :10
# Product Id : 2 | Product Name : Samsung Galaxy M14 | Product Price : 13000 | Product Quantity Avaiable :8
# Product Id : 3 | Product Name : iPhone SE | Product Price : 30000 | Product Quantity Avaiable :5
# Product Id : 4 | Product Name : Realme Narzo 60 | Product Price : 17000 | Product Quantity Avaiable :12
# Product Id : 5 | Product Name : OnePlus Nord CE | Product Price : 25000 | Product Quantity Avaiable :6
# Product Id : 6 | Product Name : Vivo T1 | Product Price : 16000 | Product Quantity Avaiable :9
# Product Id : 7 | Product Name : Poco X5 | Product Price : 18000 | Product Quantity Avaiable :7
# Product Id : 8 | Product Name : Motorola G54 | Product Price : 14000 | Product Quantity Avaiable :11
# ...

# %%
records[1]["Price"]
# Out:
# 15000

# %%
records.keys
# Out:
# <function dict.keys>
