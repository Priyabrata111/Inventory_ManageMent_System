# %% [markdown]
# ## Product Details
# 1. Product Id
# 2. Product Name
# 3. Product Price
# 4. Product Quantity

# %%
fd = open("Inventory.txt","r")
txt = fd.read()
fd.close()

# %%
txt
# Out:
# '1, Redmi Note 7 Pro, 15000, 10\n2, Samsung Galaxy M14, 13000, 8\n3, iPhone SE, 30000, 5\n4, Realme Narzo 60, 17000, 12\n5, OnePlus Nord CE, 25000, 6\n6, Vivo T1, 16000, 9\n7, Poco X5, 18000, 7\n8, Motorola G54, 14000, 11\n9, Oppo A78, 19000, 4\n10, Redmi 13C, 9000, 15'
